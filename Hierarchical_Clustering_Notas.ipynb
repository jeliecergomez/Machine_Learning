# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
#from plotnine import *

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot as plt


# %matplotlib inline

# %%
#se define un data frame para cargar el archivo que contiene los datos  
test_wide = pd.read_csv("/Machine Learning/Data/Notas.csv")

# %%
test_wide
# Out:
#     ID  Test1  Test2  Test3  Test4
# 0    1    1.5    1.0    1.0      4
# 1    2    3.3    3.0    5.0      0
# 2    3    5.0    2.5    5.0      4
# 3    4    4.0    1.0    4.0      4
# 4    5    3.3    1.0    5.0      4
# 5    6    3.3    2.5    5.0      4
# 6    7    3.3    2.5    5.0      4
# 7    8    0.0    0.0    0.0      0
# 8    9    1.0    2.5    4.5      4
# 9   10    5.0    4.0    4.5      4
# 10  11    5.0    2.0    5.0      4
# 11  12    3.3    1.5    5.0      4
# 12  13    1.5    3.0    1.0      4
# 13  14    3.3    2.5    5.0      4
# 14  15    3.3    1.0    5.0      4
# 15  16    0.0    0.0    0.0      0
# 16  17    5.0    2.0    5.0      4
# 17  18    3.3    1.5    5.0      4
# 18  19    5.0    2.0    5.0      4
# 19  20    4.0    1.0    4.0      4
# 20  21    5.0    2.0    5.0      4
# 21  22    3.3    3.5    4.5      4
# 22  23    3.3    3.5    4.5      4
# 23  24    5.0    1.5    5.0      4
# 24  25    5.0    4.0    5.0      4
# 25  26    5.0    4.0    5.0      4
# ...

# %%
features = ['Test1','Test2','Test3','Test4']
X = test_wide[features]
hac =AgglomerativeClustering(n_clusters=3,
                             affinity = 'euclidean',
                             linkage ='ward')

# %%
hac.fit(X)
dendrogr = sch.dendrogram(sch.linkage(X, method = 'ward', metric ='euclidean'))

# %%
membership = hac.labels_
membership

# %%
silhouette_score(X, membership)
# Out:
# 0.5597698948464637

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap
from matplotlib import colors
#To plot some selected features 
#Setting up colors prefrences
sns.set(rc={"axes.facecolor":"#FFF9ED","figure.facecolor":"#FFF9ED"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])
#Plotting following features
To_Plot = [ "Test1", "Test2", "Test3", "Test4"]
print("Reletive Plot Of Some Selected Features: A Data Subset")
plt.figure()
sns.pairplot(test_wide[To_Plot], hue= "Test4",palette= (["#682F2F","#F3AB60"]))
#Taking hue 
plt.show()
# Out:
# Reletive Plot Of Some Selected Features: A Data Subset
